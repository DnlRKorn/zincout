# %% [markdown]
# # ZINC ID -> purchasability -> affordability

# %%
import csv 
import numpy as np
#import smilite
import sys
import urllib
import requests

import pandas as pd
from bs4 import BeautifulSoup
import itertools

import time
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

# %% [markdown]
# ## Curation of ZINC ID list

# %%
# opens csv file with zinc ids
with open('zincids.csv', 'rt') as csvfile:
    reader = csv.reader(csvfile)
    zinc_list = list(reader)

# %%
#remove duplicates in each list
def Remove(duplicate): 
    final_list = [] 
    for num in duplicate: 
        if num not in final_list: 
            final_list.append(num) 
    return final_list

# %%
print("# without duplicates removed =",len(zinc_list))
zinc_list = Remove(zinc_list)
print('# with duplicates removed =',len(zinc_list))
# Out:
# # without duplicates removed = 95
# # with duplicates removed = 95

# %%
# get rid of brackets and quotations in values => zinc_list_2
zinc_list_2 = []
for zinc in zinc_list[1:]:
    string = str(zinc)
    zinc_list_2.append(string[2:-2]+" ")

# something weird going on with first value in zinc_list, fixing + appending
string0 = str(zinc_list[0])
zinc_list_2[0] = string0[8:-2]

print(len(zinc_list_2))
# Out:
# 94

# %%
'''
# writing csv file with purchasable ZINC IDs
purchasable = open('zinc_purchase.txt', 'w')
for zinc in zinc_list_2:
    purchasable.write(zinc)
purchasable.close()
'''
# Out:
# "\n# writing csv file with purchasable ZINC IDs\npurchasable = open('zinc_purchase.txt', 'w')\nfor zinc in zinc_list_2:\n    purchasable.write(zinc)\npurchasable.close()\n"

# %% [markdown]
# ## Fetching vendor links for each compound

# %%
cid = zinc_list_2[2]
print(cid)
# Out:
# ZINC19795634

# %%
response = requests.get("http://zinc15.docking.org/substances/" + cid + "/catitems/subsets/for-sale/table.html")
response.status_code # 200 means it was downloaded successfully
# Out:
# 200

# %%
xml = BeautifulSoup(response.content,"lxml")
#print(xml.prettify())

# %%
def vendorURLs(zinc_id_list):
    para_1 = []
    for cid in zinc_id_list:
        response = requests.get("http://zinc15.docking.org/substances/"+ cid+"/catitems/subsets/for-sale/table.html")
        xml = BeautifulSoup(response.content,"lxml")
        for i in range(0, 20):
            try:
                paragraphs = xml.find_all("td")[i]
                lines = str(paragraphs).splitlines()
                for l in lines:
                    para = str(l).splitlines()
                    for p in para:
                        if p[:12] == "<td><a href=":
                            for x in range(len(p)):
                                if p[x:x+6] == ' title':
                                    if p[12:x] not in para_1:
                                        para_1.append([p[13:x-1],cid])
            except:
                continue
    return para_1

# %%
compdlinks= vendorURLs(zinc_list_2)

# %%
file1 = open("these_are_the_mother_fucking_links.txt","a") 
for compL in compdlinks:
    for line in compL:
        if line[:6] == "mailto":
            del compL
            continue
        else:
            file1.write(line) 
            file1.write("\n")
file1.close()

# %% [markdown]
# NOT: achemblblock, Ambinter, astatechinc, biochempartner, cactus.nci.nih, chemistryondemand, combi-blocks (login),
#     hit2lead, labnetwork (~), molcore (no price listed), orderbb, orders.frontierssi,
#     otavachemicals, ox-chem, pipharm, princetonbio, rostarglobal, specs, synquestlabs (sometimes loads, req. price),
#     tocris, vitasmlab, Wonder-Chem
#     <br>
# unknown: asis, apollo scientific, echemstore, synquest

# %%
outF = open("organics.txt", "w")
for line in compdlinks:
  # write line to output file
  if "organics" in line[0]:
    outF.write(line[0])
    outF.write("\n")
outF.close()

# %% [markdown]
# ## Affordability/Vendor Filtering

# %% [markdown]
# these are all good vendors:
#     <br>cayman - DONE
#     <br>chemscene - addtl click/filter - DONE
#     <br>indofinechemical - DONE
#     <br>matrixscientific - DONE
#     <br>mcule - DONE
#     <br>medchemexpress - addtl click - DONE
#     <br>molport - DONE
#     <br>targetmol - DONE
#     <br>trc-canada - DONE
#     <br>apexbt - DONE
#     <br>abovchem - DONE
#     <br>bldpharm - DONE
#         <br>keyorganicsinc - addtl click + javascript rendering
#         <br>chem-space - javascript rendering
#         <br>enaminestore - javascript rendering - DONE
#         <br>sigmaaldrich - addtl click + javascript rendering - DONE

# %%
def Remove(duplicate): 
    final_list = [] 
    for num in duplicate: 
        if num not in final_list: 
            final_list.append(num) 
    return final_list

# %%
def findEasyVendors(urlist):
    vendors = []
    goodvendors = ["caymanchem", "chem-space", "indofinechemical", "matrixscientific", "mcule", "molport", "apexbt", 
                  "abovchem", "bldpharm", "targetmol", "trc-canada", "chemscene", "medchemexp", "sigma", "enamine"]
    for row in urlist:
        for v in goodvendors:
            if v in row[0]:
                vendors.append(row)
                break
    return vendors

# %%
easy = findEasyVendors(compdlinks)

# %%
easypeesy = []
for e in easy:
    if "sigma" not in e[0]:
        easypeesy.append(e)
    elif "|" in e[0]:
        easypeesy.append(e)

# %% [markdown]
# ### Abovchem

# %%
def abovchemPrice(urlid):
    prices = []
    size = []
    sizes = []
    units = []
    response = requests.get(urlid)
    xml = BeautifulSoup(response.content,"lxml")
    for div in xml:
        try:
            d = str(div).splitlines()
            for ind in d: 
                line = str(ind.splitlines())
                if "size: " in line:
                    for i in range(len(line)):
                        if line[i:i+6] == "size: ":
                            for j in range(len(line)):
                                if line[j:j+2] == ", ":
                                    prices.append(line[i+6:j])
                elif "className = className.replace(" in line:
                    for i in range(len(line)):
                        if line[i:i+2] == '-/':
                            for j in range(len(line)):
                                if line[j:j+2] == ", ":
                                    units.append(line[i+2:j])
                elif "count: " in line:
                    for i in range(len(line)):
                        if line[i:i+7] == "count: ":
                            for j in range(len(line)):
                                if line[j:j+2] == ", ":
                                    size.append(line[i+7:j])
        except:
            continue
                
        for x in range(len(size)):
            sizes.append(size[x]+units[x])
    aff = np.column_stack((sizes, prices))
    return aff

# %% [markdown]
# ### Apex Biotech

# %%
def apxbtPrice(urlid):
    sizes = []
    prices = []
    response = requests.get(urlid)
    xml = BeautifulSoup(response.content,"lxml")
    for z in range(0,20):
        paragraphs = xml.find_all("td")[z]
        lines = str(paragraphs).splitlines()
        for m in lines:
            for i in range(len(m)):
                if 'item-name">' == m[i:i+11]:
                    sizes.append(m[i+11:i+14].replace(" ",""))
                if '="price">' == m[i:i+9]:
                    for j in range(len(m)):
                        if "</span></span>" == m[j:j+14]:
                            prices.append(m[i+9:j])
    aff = np.column_stack((sizes,prices))
    return aff

# %% [markdown]
# ### Cayman Chemical

# %%
def caymanPrice(urlid):
    
    sizes = []
    prices = []
    response = requests.get(urlid)
    xml = BeautifulSoup(response.content,"lxml")
    for z in range(0,20):
        try:
            paragraphs = xml.find_all("td")[z]
            lines = str(paragraphs).splitlines()
            for l in lines:
                para = str(l).splitlines()
                for p in para:
                    if p[:15] == '<td class="size':
                        sizes.append(p[40:45].replace(" ",""))
                    elif p[:16] == '<td class="price':
                        prices.append(p[36:].replace(",",""))
        except:
            continue
                    
    aff = np.column_stack(((sizes, prices)))
    return aff

# %% [markdown]
# ### Chemscene

# %%
def chemscenePrice(compdurl):
    for i in range(len(compdurl)):
        if compdurl[i:i+11] == "productObj=":
            choiceID = compdurl[i+11:]

    response = requests.get(compdurl)

    casNos = []
    vendorid = []
    xml = BeautifulSoup(response.content,"lxml")
    for div in xml:
        d = str(div).splitlines()
        for ind in d: 
            line = ind.splitlines()
            if "CAS No." in str(line):
                for i in range(len(str(line))):
                    if str(line)[i:i+2] == "</":
                        casNos.append(str(line)[23:i])
            if 'class="img-responsive"' in str(line):
                for i in range(len(str(line))):
                    if str(line)[i:i+7] == ' class=':
                        vendorid.append(str(line)[12:i-1])
    while '' in casNos:
        casNos.remove('')
    crossref = np.column_stack((casNos, vendorid))

    for i in range(len(crossref)):
        if crossref[i][1] == choiceID:
            correctcas = crossref[i][0]

    sizes = []
    prices = []
    response = requests.get("https://www.chemscene.com/" + correctcas + ".html")
    xml = BeautifulSoup(response.content,"lxml")
    for div in xml:
        d = str(div).splitlines()
        for ind in d:
            if ' prctbl-size' in str(ind):
                for i in range(len(ind)):
                    if ind[i:i+8] == 'id="size':
                        line = ind[i+11:]
                        for j in range(len(ind)):
                            if line[j:j+3] == "</s":
                                sizes.append(line[:j].replace(" ",""))
            elif 's" id="price' in ind:
                for i in range(len(ind)):
                    if ind[i:i+9] == 'id="price':
                        for j in range(len(ind)):
                            if ind[j:j+8] == "</span><":
                                 prices.append(ind[i+12:j])

    aff = np.column_stack((sizes,prices))
    return aff

# %% [markdown]
# ### Enamine

# %%
# this function is not perfect, does not filter search results by stereochem, requires user to do this
def enaminePrice(urlpage):
    
    #1st and only driver call
    
    driver = webdriver.Chrome(ChromeDriverManager().install())
    driver.get(urlpage);
    innerHTML = driver.execute_script("return document.body.innerHTML")
    time.sleep(5) # lets the user see something
    html = str(innerHTML).splitlines()
    time.sleep(5) # lets the user see something
    driver.quit()
    
    #checking that valid search results page was found
    pagefound = 0
    for h in html:
        if "Sorry, nothing found matching your search criteria." in h:
            pagefound = 1
    
    # returns prices and sizes, some issue with showing results that don't exist? or maybe they do
    prices = []
    size_excl = []
    sizes = []
    if pagefound == 0:
        for h in html:
            if "$ " in h:
                for j in range(len(h)):
                    if h[j] == " ":
                        prices.append(h[j+1:])
            elif '</a></span><span class="c-price">' in h:
                if len(h) < 42:
                    for j in range(len(h)):
                        if h[j:j+4] == "</a>":
                            sizes.append(h[:j].replace(" ",""))
    '''for h in html:
        if '</a></span><span class="c-price">' in h:
            if len(h) < 42:
                val = 0
                for s in size_excl:
                    if s in h:
                        val = 1
                if val == 0:
                    for j in range(len(h)):
                        if h[j:j+4] == "</a>":
                            sizes.append(h[:j])'''

    aff = np.column_stack((sizes, prices))

    return aff

# %% [markdown]
# ### Indofine Chemical

# %%
def indofinePrice(urlid):
    sizes = []
    prices = []
    response = requests.get(urlid)
    xml = BeautifulSoup(response.content,"lxml")
    for z in range(0,20):
        paragraphs = xml.find_all("div")[z]
        lines = str(paragraphs).splitlines()
        for l in lines:
            ind = l.splitlines()
            for i in ind:
                if "gm @ $" in i[30:]:
                    sizes.append(i[28:33].replace(" ","").replace("gm","mg"))
                    prices.append(i[36:42])
    aff = np.column_stack((sizes, prices))
    return aff

# %% [markdown]
# ### Matrix Scientific

# %%
def matrixPrice(urlid):
    sizes = []
    prices = []
    response = requests.get(urlid)
    xml = BeautifulSoup(response.content,"lxml")
    for z in range(0,20):
        try:
            paragraphs = xml.find_all("td")[z]
            lines = str(paragraphs).splitlines()
            for m in lines:
                if 'class="price"' in m:
                    prices.append(m[21:27].replace(",",""))
                elif "			" in m:
                    if ("<" not in m) and ("g" in m):
                        for x in range(len(m)):
                            if m[x+1] == 'g':
                                sizes.append(m[3:x+2].replace(" ",""))
        except:
            continue
        
    aff = np.column_stack((sizes,prices))
    return aff

# %% [markdown]
# ### MCULE

# %%
def mculePrice(urlid):
    sizes = []
    prices = []
    response = requests.get(urlid)
    xml = BeautifulSoup(response.content,"lxml")
    for z in range(0,20):
        paragraphs = xml.find_all("td")[z]
        lines = str(paragraphs).splitlines()
        for m in lines:
            if "USD" in m:
                for x in range(len(m)):
                    if m[x:x+4] == ' USD':
                        prices.append(m[4:x])
                del m
            elif "g</td>" in m:
                if "class" not in m:
                    for x in range(len(m)):
                        if m[x:x+5] == '</td>':
                            sizes.append(m[4:x].replace(" ",""))
    aff = np.column_stack((sizes, prices))
    return aff

# %% [markdown]
# ### MedChem Expresss

# %%
def medchemexpPrice(urlid):
    response = requests.get(urlid)
    xml = BeautifulSoup(response.content,"lxml")

    #if there's a space in the compound name you're going to need to replace it with "-"

    # extracting compound name from the search result
    for z in range(0,20):
        try:
            paragraphs = xml.find_all("dt")[z]
            lines = str(paragraphs).splitlines()
            for l in lines:
                if "s_pro_list_cat" in l:
                    for j in range(len(l)):
                        if l[j:j+4] == 'f="/':
                            for k in range(len(l)):
                                if l[k:k+5] == ".html":
                                    compdname = (l[j+4:k].replace(" ","-"))
        except:
            continue


    # fetching actual vendor link
    prices = []
    sizes = []
    urlid = "https://www.medchemexpress.com/" + compdname+ ".html"
    response = requests.get(urlid)
    xml = BeautifulSoup(response.content,"lxml")
    for z in range(0,20):
        paragraphs = xml.find_all("td")[z]
        lines = str(paragraphs).splitlines()
        for m in lines:
            if "USD" in m:
                if "input" not in m:
                    prices.append(m[4:].replace(" ", ""))
                else:
                    for j in range(len(m)):
                        if m[j:j+3] == ";HY":
                            line = (m[:j])
                            for k in range(len(line)):
                                if line[k] == ";":
                                    sizes.append(line[k+1:].replace(" ", ""))  
                                    
    aff = np.column_stack((sizes, prices))
    return aff

# %% [markdown]
# ### MolPort

# %%
def molportPrice(urlid):
    sizes = []
    prices = []
    response = requests.get(urlid)
    xml = BeautifulSoup(response.content,"lxml")
    for div in xml:
        d = str(div).splitlines()
        for ind in d:
            if '"sku"' in ind:
                for j in range(len(ind)):
                    if ind[j] == "_":
                        indn = ind[j+1:]
                        for i in range(len(indn)):
                            if indn[i] == '"':
                                sizes.append(indn[:i])
            elif '"price"' in ind:
                for j in range(len(ind)):
                    if ind[j:j+2] == ' "':
                        for k in range(len(ind)):
                            if ind[k:k+2] == '",':
                                prices.append(ind[j+2:k])
    aff = np.column_stack((sizes, prices))
    return aff

# %% [markdown]
# ### Sigma Aldrich

# %%
def newURL(urlid):
    for x in range(len(urlid)):
        if urlid[x:x+12] == "search?term=":
            for y in range(len(urlid)):
                if urlid[y:y+4] == "&int":
                    compdname = str(urlid[x+12:y])
                    break
                elif urlid[y:y+4] == "&amp":
                    compdname = str(urlid[x+12:y])
                    break
                elif urlid[y] == "|":
                    compdname = str(urlid[x+12:y])   
                    break
    
    newurlid = "https://www.sigmaaldrich.com/catalog/search?term="+compdname+"&interface=All&N=0&mode=match%20partialmax&lang=en&region=US&focus=product"              

    return newurlid

# %%
def sigmaPrice(urlpage):
    
    urlpage2 = newURL(urlpage) #transforming url because sigma aldrich sucks
    
    #first driver call
    
    driver = webdriver.Chrome(ChromeDriverManager().install())
    driver.get(urlpage2);
    innerHTML = driver.execute_script("return document.body.innerHTML")
    time.sleep(5) # lets the user see something

    html = str(innerHTML).splitlines()

    time.sleep(5) # lets the user see something
    driver.quit()
    
    #What's the real compound name because this wasn't already convoluted enough

    compdname = ""
    for h in html:
        if "breadcrumbOriginalTextSearched" in h:
            for x in range(len(h)):
                if h[x:x+7] == 'ched">"':
                    for y in range(len(h)):
                        if h[y:y+13] == '"</span><span':
                            compdname = h[x+7:y].lower()
    
    #Sigma Aldrich's url formatting can go to hell

    if "|" in urlpage:
        if "USP" in urlpage:
            urlpage3 = "https://www.sigmaaldrich.com/catalog/product/usp/" + compdname + "?lang=en&region=US.php"
        elif "VETEC" in urlpage:
            urlpage3 = "https://www.sigmaaldrich.com/catalog/product/vetec/" + compdname + "?lang=en&region=US.php"
        elif "SIGMA" in urlpage:
            urlpage3 = "https://www.sigmaaldrich.com/catalog/product/sigma/" + compdname + "?lang=en&region=US"
        elif "SIAL" in urlpage:
            urlpage3 = "https://www.sigmaaldrich.com/catalog/product/sial/" + compdname + "?lang=en&region=US"
        else: 
            urlpage3 = 'https://www.sigmaaldrich.com/catalog/product/aldrich/' + compdname + '?lang=en&region=US.php'
    else:
        urlpage3 = 'https://www.sigmaaldrich.com/catalog/product/aldrich/' + compdname + '?lang=en&region=US.php'

    # 2nd driver call
    
    if compdname != "":
        driver = webdriver.Chrome(ChromeDriverManager().install())

        driver.get(urlpage3);
        innerHTML = driver.execute_script("return document.body.innerHTML")
        time.sleep(5) # lets the user see something

        html = str(innerHTML).splitlines()

        time.sleep(5) # lets the user see something
        driver.quit()
    
    #making sure page loads
    
    error404 = 0
    for h in html:
        if "sorry" in h:
            error404 = 1
            
    #making sure product is in stock
    
    discontinued = 0
    for h in html:
        if "discontinued" in h:
            discontinued = 1
        if "still have inventory in stock" in h:
            discontinued = 0

    # finally fetch prices and package sizes
    
    sizes = []
    prices = []
    val = compdname.upper() +"-"

    if error404 == 0:
        if discontinued == 0:
            if compdname != "":
                for h in html:
                    if val in h:
                        d = str(h).split()
                        for ind in d:
                            if "row" in ind: #"CASS" doesn't work
                                for x in range(len(ind)):
                                    if ind[x] == "-":
                                        size = ind[x+1:].replace('"><td','')
                                        sizes.append(size.lower())
                    if "USD" in h:
                        d = str(h).split()
                        for ind in d:
                            for x in range(len(ind)):
                                if ind[x:x+6] == "USD#@#":
                                    for y in range(len(h)):
                                        if ind[y:y+10] == '"></td><td':
                                            prices.append(ind[x+6:y])
    
    aff = np.column_stack((sizes, prices))
    
    return aff

# %% [markdown]
# ### Targetmol

# %%
def targetmolPrice(urlid):
    sizes = []
    prices = []
    response = requests.get(urlid)
    xml = BeautifulSoup(response.content,"lxml")
    for z in range(0,20):
        paragraphs = xml.find_all("td")[z]
        lines = str(paragraphs).splitlines()
        mat = lines[0].splitlines()
        for m in mat:
            if "." in str(m):
                for x in range(len(m)):
                    if m[x:x+5] == '</td>':
                        prices.append(m[4:x])
                del m
            elif " " in m:
                if "<p" not in m:
                    if "td " not in m:
                        for x in range(len(m)):
                            if m[x:x+5] == '</td>':
                                sizes.append(m[4:x].replace(" ",""))
    aff = np.column_stack((sizes, prices))
    return aff

# %% [markdown]
# ### Toronto Research Chemicals - Canada

# %%
def trcPrice(urlid):
    prices = []
    sizes = []
    pr = []
    response = requests.get(urlid)
    xml = BeautifulSoup(response.content,"lxml")
    for z in range(0,20):
        paragraphs = xml.find_all("div")[z]
        lines = str(paragraphs).splitlines()
        for m in lines:
            if "g</td>" in m:
                if "id" not in m:
                    for x in range(len(m)):
                        if m[x:x+2] == "</":
                            sizes.append(m[23:x].replace(" ",""))
            elif '<td class="optionscol">' in m:
                if '.' in m:
                    for j in range(len(m)):
                        if m[j:j+2] == "  ":
                            for i in range(len(m)):
                                if m[i] == "$":
                                    pr.append(m[i+1:j].replace(" ",""))
    prices = Remove(pr)
    aff = np.column_stack((sizes,prices))
    return aff

# %% [markdown]
# ## Vendor Prices

# %%
start = time.time()

buylist = []
for url in easypeesy:
    if "abovchem" in url[0]:
        aff = abovchemPrice(url[0])
        length = len(aff)
        rep = list(itertools.repeat(url, length))
        aff_2 = np.column_stack((aff, rep))
        buylist.append(aff_2)
    elif "apxbt" in url[0]:
        aff = apxbtPrice(url[0])
        length = len(aff)
        rep = list(itertools.repeat(url, length))
        aff_2 = np.column_stack((aff, rep))
        buylist.append(aff_2)
    elif "cayman" in url[0]:
        aff = caymanPrice(url[0])
        length = len(aff)
        rep = list(itertools.repeat(url, length))
        aff_2 = np.column_stack((aff, rep))
        buylist.append(aff_2)
    elif "chemscene" in url[0]:
        aff = chemscenePrice(url[0])
        length = len(aff)
        rep = list(itertools.repeat(url, length))
        aff_2 = np.column_stack((aff, rep))
        buylist.append(aff_2)
    elif "indofine" in url[0]:
        aff = indofinePrice(url[0])
        length = len(aff)
        rep = list(itertools.repeat(url, length))
        aff_2 = np.column_stack((aff, rep))
        buylist.append(aff_2)
    elif "matrixscientific" in url[0]:
        aff = matrixPrice(url[0])
        length = len(aff)
        rep = list(itertools.repeat(url, length))
        aff_2 = np.column_stack((aff, rep))
        buylist.append(aff_2)
    elif "mcule" in url[0]:
        aff = mculePrice(url[0])
        length = len(aff)
        rep = list(itertools.repeat(url, length))
        aff_2 = np.column_stack((aff, rep))
        buylist.append(aff_2)
    elif "medchemexp" in url[0]:
        aff = medchemexpPrice(url[0])
        length = len(aff)
        rep = list(itertools.repeat(url, length))
        aff_2 = np.column_stack((aff, rep))
        buylist.append(aff_2)
    elif "molport" in url[0]:
        aff = molportPrice(url[0])
        length = len(aff)
        rep = list(itertools.repeat(url, length))
        aff_2 = np.column_stack((aff, rep))
        buylist.append(aff_2)
    elif "targetmol" in url[0]:
        aff = targetmolPrice(url[0])
        length = len(aff)
        rep = list(itertools.repeat(url, length))
        aff_2 = np.column_stack((aff, rep))
        buylist.append(aff_2)
    elif "trc-canada" in url[0]:
        aff = trcPrice(url[0])
        length = len(aff)
        rep = list(itertools.repeat(url, length))
        aff_2 = np.column_stack((aff, rep))
        buylist.append(aff_2)
    elif "sigma" in url[0]:
        aff = sigmaPrice(url[0])
        length = len(aff)
        rep = list(itertools.repeat(url, length))
        aff_2 = np.column_stack((aff, rep))
        buylist.append(aff_2)

end = time.time()
print(end - start)
# Out:
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
#
# Checking for mac64 chromedriver:75.0.3770.140 in cache
# Driver found in /Users/tesiabobrowski/.wdm/chromedriver/75.0.3770.140/mac64/chromedriver
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      59
# ---> 60     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61         af, socktype, proto, canonname, sa = res
#
# ~/anaconda3/lib/python3.6/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     744     addrlist = []
# --> 745     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     746         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     149             raise NewConnectionError(
# --> 150                 self, "Failed to establish a new connection: %s" % e)
#     151
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x1150304e0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPSConnectionPool(host='www.molport.com', port=443): Max retries exceeded with url: /shop/molecule-link/MolPort-005-828-923 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1150304e0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-119-f24431538c5b> in <module>()
#      52         buylist.append(aff_2)
#      53     elif "molport" in url[0]:
# ---> 54         aff = molportPrice(url[0])
#      55         length = len(aff)
#      56         rep = list(itertools.repeat(url, length))
#
# <ipython-input-114-b4369cb89314> in molportPrice(urlid)
#       2     sizes = []
#       3     prices = []
# ----> 4     response = requests.get(urlid)
#       5     xml = BeautifulSoup(response.content,"lxml")
#       6     for div in xml:
#
# ~/anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~/anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     506                 raise SSLError(e, request=request)
#     507
# --> 508             raise ConnectionError(e, request=request)
#     509
#     510         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='www.molport.com', port=443): Max retries exceeded with url: /shop/molecule-link/MolPort-005-828-923 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1150304e0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))

# %%
for b in buylist:
    print(b)
# Out:
# [['5mg' '350.0'
#   'http://www.chemscene.com/goproductList/searchProductList?productObj=CS-0047'
#   'ZINC19795634 ']]
# [['1mg' '36.00'
#   'http://www.caymanchem.com/app/template/Product.vm/catalog/10011249'
#   'ZINC19795634 ']
#  ['5mg' '162.00'
#   'http://www.caymanchem.com/app/template/Product.vm/catalog/10011249'
#   'ZINC19795634 ']
#  ['10mg' '288.00'
#   'http://www.caymanchem.com/app/template/Product.vm/catalog/10011249'
#   'ZINC19795634 ']
#  ['50mg' '1260.00'
#   'http://www.caymanchem.com/app/template/Product.vm/catalog/10011249'
#   'ZINC19795634 ']]
# [['1g' '133.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=SYX00317|ALDRICH&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC06665770 ']]
# [['1mg' '174.00' 'https://indofinechemical.com/details.aspx?Sku=08-1534'
#   'ZINC06665770 ']
#  ['5mg' '376.00' 'https://indofinechemical.com/details.aspx?Sku=08-1534'
#   'ZINC06665770 ']
#  ['1mg' '174.00' 'https://indofinechemical.com/details.aspx?Sku=08-1534'
#   'ZINC06665770 ']
#  ['5mg' '376.00' 'https://indofinechemical.com/details.aspx?Sku=08-1534'
#   'ZINC06665770 ']]
# []
# [['200mg' '313.60'
#   'http://www.sigmaaldrich.com/catalog/search?term=1012101|USP&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC00000882 ']]
# []
# []
# [['1g' '53.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=CDS019917|ALDRICH&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC00000882 ']]
# []
# [['5mg' '72.0'
#   'http://www.chemscene.com/goproductList/searchProductList?productObj=CS-0259'
#   'ZINC03986669 ']
#  ['10mg' '132.0'
#   'http://www.chemscene.com/goproductList/searchProductList?productObj=CS-0259'
#   'ZINC03986669 ']
#  ['25mg' '288.0'
#   'http://www.chemscene.com/goproductList/searchProductList?productObj=CS-0259'
#   'ZINC03986669 ']
#  ['50mg' '444.0'
#   'http://www.chemscene.com/goproductList/searchProductList?productObj=CS-0259'
#   'ZINC03986669 ']
#  ['100mg' '600.0'
#   'http://www.chemscene.com/goproductList/searchProductList?productObj=CS-0259'
#   'ZINC03986669 ']
#  ['200mg' '1080.0'
#   'http://www.chemscene.com/goproductList/searchProductList?productObj=CS-0259'
#   'ZINC03986669 ']]
# [['5mg' '60.00' 'https://www.targetmol.com/search?keyword=T1830'
#   'ZINC03986669 ']
#  ['10mg' '111.00' 'https://www.targetmol.com/search?keyword=T1830'
#   'ZINC03986669 ']
#  ['25mg' '245.00' 'https://www.targetmol.com/search?keyword=T1830'
#   'ZINC03986669 ']
#  ['50mg' '400.00' 'https://www.targetmol.com/search?keyword=T1830'
#   'ZINC03986669 ']
#  ['100mg' '600.00' 'https://www.targetmol.com/search?keyword=T1830'
#   'ZINC03986669 ']]
# [['5mg' '149.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=B1427|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC02043204 ']]
# [['10mg' '51.00' 'https://www.targetmol.com/search?keyword=T6250'
#   'ZINC02043204 ']
#  ['25mg' '99.00' 'https://www.targetmol.com/search?keyword=T6250'
#   'ZINC02043204 ']
#  ['50mg' '182.00' 'https://www.targetmol.com/search?keyword=T6250'
#   'ZINC02043204 ']
#  ['100mg' '326.00' 'https://www.targetmol.com/search?keyword=T6250'
#   'ZINC02043204 ']
#  ['200mg' '593.00' 'https://www.targetmol.com/search?keyword=T6250'
#   'ZINC02043204 ']]
# [['5mg' '150.00'
#   'https://www.molport.com/shop/molecule-link/MolPort-042-665-730'
#   'ZINC39280116 ']
#  ['25mg' '510.00'
#   'https://www.molport.com/shop/molecule-link/MolPort-042-665-730'
#   'ZINC39280116 ']]
# [['1g' '29.90'
#   'http://www.sigmaaldrich.com/catalog/search?term=A95502|ALDRICH&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC15442276 ']
#  ['5g' '68.80'
#   'http://www.sigmaaldrich.com/catalog/search?term=A95502|ALDRICH&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC15442276 ']]
# [['5mg' '113.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=PZ0117|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC35636073 ']
#  ['25mg' '447.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=PZ0117|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC35636073 ']]
# [['5mg' '61.00' 'https://www.targetmol.com/search?keyword=T2001'
#   'ZINC35636073 ']
#  ['10mg' '110.00' 'https://www.targetmol.com/search?keyword=T2001'
#   'ZINC35636073 ']
#  ['25mg' '231.00' 'https://www.targetmol.com/search?keyword=T2001'
#   'ZINC35636073 ']
#  ['50mg' '417.00' 'https://www.targetmol.com/search?keyword=T2001'
#   'ZINC35636073 ']
#  ['100mg' '751.00' 'https://www.targetmol.com/search?keyword=T2001'
#   'ZINC35636073 ']]
# [['10mM*1mLinDMSO' '134'
#   'https://www.medchemexpress.com/search.html?q=HY-10461&amp;ft=&amp;fa=&amp;fp='
#   'ZINC35636073 ']
#  ['10mg' '122'
#   'https://www.medchemexpress.com/search.html?q=HY-10461&amp;ft=&amp;fa=&amp;fp='
#   'ZINC35636073 ']
#  ['50mg' '479'
#   'https://www.medchemexpress.com/search.html?q=HY-10461&amp;ft=&amp;fa=&amp;fp='
#   'ZINC35636073 ']
#  ['100mg' '900'
#   'https://www.medchemexpress.com/search.html?q=HY-10461&amp;ft=&amp;fa=&amp;fp='
#   'ZINC35636073 ']]
# [['10mg' '220.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=T0826|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC03870968 ']]
# [['10mM*1mLinDMSO' '106'
#   'https://www.medchemexpress.com/search.html?q=HY-15535&amp;ft=&amp;fa=&amp;fp='
#   'ZINC08830553 ']
#  ['10mg' '96'
#   'https://www.medchemexpress.com/search.html?q=HY-15535&amp;ft=&amp;fa=&amp;fp='
#   'ZINC08830553 ']
#  ['50mg' '343'
#   'https://www.medchemexpress.com/search.html?q=HY-15535&amp;ft=&amp;fa=&amp;fp='
#   'ZINC08830553 ']]
# [['5mg' '164.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=P0036|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC20148984 ']
#  ['25mg' '654.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=P0036|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC20148984 ']]
# [['10mM*1mLinDMSO' '119'
#   'https://www.medchemexpress.com/search.html?q=HY-10372&amp;ft=&amp;fa=&amp;fp='
#   'ZINC20148984 ']
#  ['10mg' '108'
#   'https://www.medchemexpress.com/search.html?q=HY-10372&amp;ft=&amp;fa=&amp;fp='
#   'ZINC20148984 ']
#  ['50mg' '300'
#   'https://www.medchemexpress.com/search.html?q=HY-10372&amp;ft=&amp;fa=&amp;fp='
#   'ZINC20148984 ']
#  ['100mg' '474'
#   'https://www.medchemexpress.com/search.html?q=HY-10372&amp;ft=&amp;fa=&amp;fp='
#   'ZINC20148984 ']]
# [['1mg' '55.00'
#   'http://www.caymanchem.com/app/template/Product.vm/catalog/20453'
#   'ZINC48998306 ']
#  ['5mg' '179.00'
#   'http://www.caymanchem.com/app/template/Product.vm/catalog/20453'
#   'ZINC48998306 ']]
# [['5mg' '52.00' 'https://www.targetmol.com/search?keyword=T2234'
#   'ZINC00244029 ']
#  ['10mg' '82.00' 'https://www.targetmol.com/search?keyword=T2234'
#   'ZINC00244029 ']
#  ['25mg' '169.00' 'https://www.targetmol.com/search?keyword=T2234'
#   'ZINC00244029 ']
#  ['50mg' '293.00' 'https://www.targetmol.com/search?keyword=T2234'
#   'ZINC00244029 ']
#  ['100mg' '527.00' 'https://www.targetmol.com/search?keyword=T2234'
#   'ZINC00244029 ']]
# [['5mg' '83.90'
#   'http://www.sigmaaldrich.com/catalog/search?term=BM0019|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC39716080 ']
#  ['25mg' '338.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=BM0019|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC39716080 ']]
# [['5mg' '108.0'
#   'http://www.chemscene.com/goproductList/searchProductList?productObj=CS-5551'
#   'ZINC58541155 ']
#  ['10mg' '180.0'
#   'http://www.chemscene.com/goproductList/searchProductList?productObj=CS-5551'
#   'ZINC58541155 ']
#  ['25mg' '360.0'
#   'http://www.chemscene.com/goproductList/searchProductList?productObj=CS-5551'
#   'ZINC58541155 ']
#  ['50mg' '648.0'
#   'http://www.chemscene.com/goproductList/searchProductList?productObj=CS-5551'
#   'ZINC58541155 ']
#  ['100mg' '1152.0'
#   'http://www.chemscene.com/goproductList/searchProductList?productObj=CS-5551'
#   'ZINC58541155 ']]
# [['2mg' '62.00' 'https://www.targetmol.com/search?keyword=T3196'
#   'ZINC58541155 ']
#  ['5mg' '112.00' 'https://www.targetmol.com/search?keyword=T3196'
#   'ZINC58541155 ']
#  ['10mg' '180.00' 'https://www.targetmol.com/search?keyword=T3196'
#   'ZINC58541155 ']
#  ['25mg' '347.00' 'https://www.targetmol.com/search?keyword=T3196'
#   'ZINC58541155 ']
#  ['50mg' '606.00' 'https://www.targetmol.com/search?keyword=T3196'
#   'ZINC58541155 ']]
# [['10mM*1mLinDMSO' '130'
#   'https://www.medchemexpress.com/search.html?q=HY-10943&amp;ft=&amp;fa=&amp;fp='
#   'ZINC58541155 ']
#  ['5mg' '108'
#   'https://www.medchemexpress.com/search.html?q=HY-10943&amp;ft=&amp;fa=&amp;fp='
#   'ZINC58541155 ']
#  ['10mg' '180'
#   'https://www.medchemexpress.com/search.html?q=HY-10943&amp;ft=&amp;fa=&amp;fp='
#   'ZINC58541155 ']
#  ['25mg' '360'
#   'https://www.medchemexpress.com/search.html?q=HY-10943&amp;ft=&amp;fa=&amp;fp='
#   'ZINC58541155 ']]
# [['1mg' '110.0'
#   'http://www.chemscene.com/goproductList/searchProductList?productObj=CS-0405'
#   'ZINC16052239 ']
#  ['5mg' '330.0'
#   'http://www.chemscene.com/goproductList/searchProductList?productObj=CS-0405'
#   'ZINC16052239 ']
#  ['10mg' '590.0'
#   'http://www.chemscene.com/goproductList/searchProductList?productObj=CS-0405'
#   'ZINC16052239 ']]
# [['10mM*1mLinDMSO' '289'
#   'https://www.medchemexpress.com/search.html?q=HY-10425&amp;ft=&amp;fa=&amp;fp='
#   'ZINC16052239 ']
#  ['1mg' '110'
#   'https://www.medchemexpress.com/search.html?q=HY-10425&amp;ft=&amp;fa=&amp;fp='
#   'ZINC16052239 ']
#  ['5mg' '330'
#   'https://www.medchemexpress.com/search.html?q=HY-10425&amp;ft=&amp;fa=&amp;fp='
#   'ZINC16052239 ']
#  ['10mg' '590'
#   'https://www.medchemexpress.com/search.html?q=HY-10425&amp;ft=&amp;fa=&amp;fp='
#   'ZINC16052239 ']]
# [['500µ' '85.00'
#   'http://www.caymanchem.com/app/template/Product.vm/catalog/16499'
#   'ZINC16052239 ']
#  ['1mg' '162.00'
#   'http://www.caymanchem.com/app/template/Product.vm/catalog/16499'
#   'ZINC16052239 ']
#  ['5mg' '680.00'
#   'http://www.caymanchem.com/app/template/Product.vm/catalog/16499'
#   'ZINC16052239 ']]
# [['10mM*1mLinDMSO' '462'
#   'https://www.medchemexpress.com/search.html?q=HY-14403&amp;ft=&amp;fa=&amp;fp='
#   'ZINC66066276 ']
#  ['5mg' '420'
#   'https://www.medchemexpress.com/search.html?q=HY-14403&amp;ft=&amp;fa=&amp;fp='
#   'ZINC66066276 ']
#  ['10mg' '600'
#   'https://www.medchemexpress.com/search.html?q=HY-14403&amp;ft=&amp;fa=&amp;fp='
#   'ZINC66066276 ']
#  ['50mg' '1800'
#   'https://www.medchemexpress.com/search.html?q=HY-14403&amp;ft=&amp;fa=&amp;fp='
#   'ZINC66066276 ']
#  ['100mg' '2520'
#   'https://www.medchemexpress.com/search.html?q=HY-14403&amp;ft=&amp;fa=&amp;fp='
#   'ZINC66066276 ']]
# [['5mg' '120.0'
#   'http://www.chemscene.com/goproductList/searchProductList?productObj=CS-5860'
#   'ZINC58633224 ']
#  ['10mg' '180.0'
#   'http://www.chemscene.com/goproductList/searchProductList?productObj=CS-5860'
#   'ZINC58633224 ']
#  ['25mg' '348.0'
#   'http://www.chemscene.com/goproductList/searchProductList?productObj=CS-5860'
#   'ZINC58633224 ']
#  ['50mg' '588.0'
#   'http://www.chemscene.com/goproductList/searchProductList?productObj=CS-5860'
#   'ZINC58633224 ']
#  ['100mg' '948.0'
#   'http://www.chemscene.com/goproductList/searchProductList?productObj=CS-5860'
#   'ZINC58633224 ']]
# [['10mM*1mLinDMSO' '132'
#   'https://www.medchemexpress.com/search.html?q=HY-14975&amp;ft=&amp;fa=&amp;fp='
#   'ZINC58633224 ']
#  ['5mg' '120'
#   'https://www.medchemexpress.com/search.html?q=HY-14975&amp;ft=&amp;fa=&amp;fp='
#   'ZINC58633224 ']
#  ['10mg' '180'
#   'https://www.medchemexpress.com/search.html?q=HY-14975&amp;ft=&amp;fa=&amp;fp='
#   'ZINC58633224 ']
#  ['25mg' '348'
#   'https://www.medchemexpress.com/search.html?q=HY-14975&amp;ft=&amp;fa=&amp;fp='
#   'ZINC58633224 ']
#  ['50mg' '588'
#   'https://www.medchemexpress.com/search.html?q=HY-14975&amp;ft=&amp;fa=&amp;fp='
#   'ZINC58633224 ']]
# [['1mg' '114.00' 'https://www.targetmol.com/search?keyword=T6927'
#   'ZINC30691792 ']
#  ['2mg' '205.00' 'https://www.targetmol.com/search?keyword=T6927'
#   'ZINC30691792 ']
#  ['5mg' '377.00' 'https://www.targetmol.com/search?keyword=T6927'
#   'ZINC30691792 ']
#  ['10mg' '678.00' 'https://www.targetmol.com/search?keyword=T6927'
#   'ZINC30691792 ']
#  ['1mL*10mM(inDMSO)' '377.00'
#   'https://www.targetmol.com/search?keyword=T6927' 'ZINC30691792 ']]
# [['1mg' '200.00'
#   'https://www.trc-canada.com/product-detail/?CatNum=P167500'
#   'ZINC30691792 ']
#  ['5mg' '900.00'
#   'https://www.trc-canada.com/product-detail/?CatNum=P167500'
#   'ZINC30691792 ']
#  ['25mg' '3500.00'
#   'https://www.trc-canada.com/product-detail/?CatNum=P167500'
#   'ZINC30691792 ']
#  ['2mg' '385.00'
#   'https://www.trc-canada.com/product-detail/?CatNum=P167500'
#   'ZINC30691792 ']
#  ['10mg' '1600.00'
#   'https://www.trc-canada.com/product-detail/?CatNum=P167500'
#   'ZINC30691792 ']]
# [['10mg' '175.82'
#   'https://www.molport.com/shop/molecule-link/MolPort-001-773-508'
#   'ZINC02577648 ']
#  ['50mg' '680.86'
#   'https://www.molport.com/shop/molecule-link/MolPort-001-773-508'
#   'ZINC02577648 ']]
# [['1mg' '80.30'
#   'http://www.sigmaaldrich.com/catalog/search?term=B3306|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC02560262 ']
#  ['5mg' '270.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=B3306|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC02560262 ']]
# [['1mg' '111.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=B3931|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC03801072 ']
#  ['5mg' '429.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=B3931|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC03801072 ']]
# [['1mg' '111.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=B3931|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC03871742 ']
#  ['5mg' '429.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=B3931|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC03871742 ']]
# []
# [['1mg' '172.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=S8307|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC03815700 ']]
# [['10mM*1mLinDMSO' '66'
#   'https://www.medchemexpress.com/search.html?q=HY-10256A&amp;ft=&amp;fa=&amp;fp='
#   'ZINC03815700 ']
#  ['10mg' '60'
#   'https://www.medchemexpress.com/search.html?q=HY-10256A&amp;ft=&amp;fa=&amp;fp='
#   'ZINC03815700 ']
#  ['50mg' '96'
#   'https://www.medchemexpress.com/search.html?q=HY-10256A&amp;ft=&amp;fa=&amp;fp='
#   'ZINC03815700 ']
#  ['100mg' '144'
#   'https://www.medchemexpress.com/search.html?q=HY-10256A&amp;ft=&amp;fa=&amp;fp='
#   'ZINC03815700 ']]
# [['1mg' '172.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=S8307|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC18274812 ']]
# [['10mM*1mLinDMSO' '66'
#   'https://www.medchemexpress.com/search.html?q=HY-10256A&amp;ft=&amp;fa=&amp;fp='
#   'ZINC18274812 ']
#  ['10mg' '60'
#   'https://www.medchemexpress.com/search.html?q=HY-10256A&amp;ft=&amp;fa=&amp;fp='
#   'ZINC18274812 ']
#  ['50mg' '96'
#   'https://www.medchemexpress.com/search.html?q=HY-10256A&amp;ft=&amp;fa=&amp;fp='
#   'ZINC18274812 ']
#  ['100mg' '144'
#   'https://www.medchemexpress.com/search.html?q=HY-10256A&amp;ft=&amp;fa=&amp;fp='
#   'ZINC18274812 ']]
# [['10mM*1mLinDMSO' '66'
#   'https://www.medchemexpress.com/search.html?q=HY-10256&amp;ft=&amp;fa=&amp;fp='
#   'ZINC18274812 ']
#  ['10mg' '60'
#   'https://www.medchemexpress.com/search.html?q=HY-10256&amp;ft=&amp;fa=&amp;fp='
#   'ZINC18274812 ']
#  ['50mg' '96'
#   'https://www.medchemexpress.com/search.html?q=HY-10256&amp;ft=&amp;fa=&amp;fp='
#   'ZINC18274812 ']
#  ['100mg' '144'
#   'https://www.medchemexpress.com/search.html?q=HY-10256&amp;ft=&amp;fa=&amp;fp='
#   'ZINC18274812 ']]
# [['250mg' '462.00' 'http://www.matrixscientific.com/071672.html'
#   'ZINC02560263 ']
#  ['1g' '998.00' 'http://www.matrixscientific.com/071672.html'
#   'ZINC02560263 ']]
# [['1mg' '51.00'
#   'http://www.caymanchem.com/app/template/Product.vm/catalog/13300'
#   'ZINC02560263 ']
#  ['5mg' '230.00'
#   'http://www.caymanchem.com/app/template/Product.vm/catalog/13300'
#   'ZINC02560263 ']
#  ['10mg' '408.00'
#   'http://www.caymanchem.com/app/template/Product.vm/catalog/13300'
#   'ZINC02560263 ']
#  ['25mg' '893.00'
#   'http://www.caymanchem.com/app/template/Product.vm/catalog/13300'
#   'ZINC02560263 ']]
# [['1mg' '75.52'
#   'https://www.molport.com/shop/molecule-link/MolPort-003-823-712'
#   'ZINC02560263 ']
#  ['5mg' '339.84'
#   'https://www.molport.com/shop/molecule-link/MolPort-003-823-712'
#   'ZINC02560263 ']
#  ['10mg' '601.80'
#   'https://www.molport.com/shop/molecule-link/MolPort-003-823-712'
#   'ZINC02560263 ']
#  ['25mg' '1318.06'
#   'https://www.molport.com/shop/molecule-link/MolPort-003-823-712'
#   'ZINC02560263 ']
#  ['1g' '554.73'
#   'https://www.molport.com/shop/molecule-link/MolPort-003-823-712'
#   'ZINC02560263 ']
#  ['1g' '500.00'
#   'https://www.molport.com/shop/molecule-link/MolPort-003-823-712'
#   'ZINC02560263 ']
#  ['5g' '2000.00'
#   'https://www.molport.com/shop/molecule-link/MolPort-003-823-712'
#   'ZINC02560263 ']
#  ['1g' '520.94'
#   'https://www.molport.com/shop/molecule-link/MolPort-003-823-712'
#   'ZINC02560263 ']]
# [['5mg' '83.90'
#   'http://www.sigmaaldrich.com/catalog/search?term=SML1638|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC13493055 ']
#  ['25mg' '338.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=SML1638|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC13493055 ']]
# [['2mg' '52.00' 'https://www.targetmol.com/search?keyword=T6089'
#   'ZINC13493055 ']
#  ['10mg' '110.00' 'https://www.targetmol.com/search?keyword=T6089'
#   'ZINC13493055 ']
#  ['25mg' '220.00' 'https://www.targetmol.com/search?keyword=T6089'
#   'ZINC13493055 ']
#  ['1mL*10mM(inDMSO)' '94.00'
#   'https://www.targetmol.com/search?keyword=T6089' 'ZINC13493055 ']]
# [['10mg' '56.00' 'https://www.targetmol.com/search?keyword=T1725'
#   'ZINC00006989 ']
#  ['25mg' '124.00' 'https://www.targetmol.com/search?keyword=T1725'
#   'ZINC00006989 ']
#  ['50mg' '168.00' 'https://www.targetmol.com/search?keyword=T1725'
#   'ZINC00006989 ']
#  ['100mg' '280.00' 'https://www.targetmol.com/search?keyword=T1725'
#   'ZINC00006989 ']
#  ['200mg' '440.00' 'https://www.targetmol.com/search?keyword=T1725'
#   'ZINC00006989 ']]
# [['.1mg' '201.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=K3761|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC03873013 ']]
# [['10mg' '140.00'
#   'https://www.trc-canada.com/product-detail/?CatNum=B448500'
#   'ZINC02011710 ']
#  ['100mg' '1120.00'
#   'https://www.trc-canada.com/product-detail/?CatNum=B448500'
#   'ZINC02011710 ']]
# [['1mg' '40.00'
#   'http://www.caymanchem.com/app/template/Product.vm/catalog/13333'
#   'ZINC02011710 ']
#  ['5mg' '149.00'
#   'http://www.caymanchem.com/app/template/Product.vm/catalog/13333'
#   'ZINC02011710 ']
#  ['10mg' '280.00'
#   'http://www.caymanchem.com/app/template/Product.vm/catalog/13333'
#   'ZINC02011710 ']]
# [['1mg' '159.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=R136|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC03797930 ']
#  ['5mg' '630.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=R136|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC03797930 ']]
# [['10mg' '180.0'
#   'http://www.chemscene.com/goproductList/searchProductList?productObj=CS-1677'
#   'ZINC03797930 ']
#  ['50mg' '540.0'
#   'http://www.chemscene.com/goproductList/searchProductList?productObj=CS-1677'
#   'ZINC03797930 ']]
# [['2mg' '50.00' 'https://www.targetmol.com/search?keyword=T6643'
#   'ZINC03797930 ']
#  ['5mg' '83.00' 'https://www.targetmol.com/search?keyword=T6643'
#   'ZINC03797930 ']
#  ['10mg' '150.00' 'https://www.targetmol.com/search?keyword=T6643'
#   'ZINC03797930 ']
#  ['25mg' '270.00' 'https://www.targetmol.com/search?keyword=T6643'
#   'ZINC03797930 ']
#  ['50mg' '434.00' 'https://www.targetmol.com/search?keyword=T6643'
#   'ZINC03797930 ']]
# []
# []
# [['5mg' '314.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=H139|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC00006486 ']
#  ['10mg' '490.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=H139|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC00006486 ']]
# [['10mg' '63.50'
#   'http://www.sigmaaldrich.com/catalog/search?term=CDS021620|ALDRICH&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC00006486 ']]
# [['1mg' '721.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=G2911|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC00585151 ']]
# [['250ug' '62.80'
#   'http://www.sigmaaldrich.com/catalog/search?term=B6292|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC00585151 ']
#  ['1mg' '171.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=B6292|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC00585151 ']]
# [['1mg' '102.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=P215|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC01420826 ']
#  ['5mg' '150.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=P215|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC01420826 ']]
# [['10mg' '50.00' 'https://www.targetmol.com/search?keyword=T2623'
#   'ZINC01420826 ']
#  ['50mg' '104.00' 'https://www.targetmol.com/search?keyword=T2623'
#   'ZINC01420826 ']
#  ['100mg' '176.00' 'https://www.targetmol.com/search?keyword=T2623'
#   'ZINC01420826 ']
#  ['200mg' '246.00' 'https://www.targetmol.com/search?keyword=T2623'
#   'ZINC01420826 ']
#  ['1mL*10mM(inDMSO)' '52.00'
#   'https://www.targetmol.com/search?keyword=T2623' 'ZINC01420826 ']]
# [['5mg' '103.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=SML1338|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC28563889 ']
#  ['25mg' '393.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=SML1338|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC28563889 ']]
# [['1mg' '35.00'
#   'http://www.caymanchem.com/app/template/Product.vm/catalog/21229'
#   'ZINC01550170 ']
#  ['5mg' '96.00'
#   'http://www.caymanchem.com/app/template/Product.vm/catalog/21229'
#   'ZINC01550170 ']
#  ['10mg' '175.00'
#   'http://www.caymanchem.com/app/template/Product.vm/catalog/21229'
#   'ZINC01550170 ']]
# [['10mg' '50.00' 'https://www.targetmol.com/search?keyword=T6277'
#   'ZINC24044436 ']
#  ['50mg' '104.00' 'https://www.targetmol.com/search?keyword=T6277'
#   'ZINC24044436 ']
#  ['100mg' '144.00' 'https://www.targetmol.com/search?keyword=T6277'
#   'ZINC24044436 ']
#  ['200mg' '264.00' 'https://www.targetmol.com/search?keyword=T6277'
#   'ZINC24044436 ']
#  ['1mL*10mM(inDMSO)' '50.00'
#   'https://www.targetmol.com/search?keyword=T6277' 'ZINC24044436 ']]
# [['10mM*1mLinDMSO' '66'
#   'https://www.medchemexpress.com/search.html?q=HY-10320&amp;ft=&amp;fa=&amp;fp='
#   'ZINC24044436 ']
#  ['10mg' '60'
#   'https://www.medchemexpress.com/search.html?q=HY-10320&amp;ft=&amp;fa=&amp;fp='
#   'ZINC24044436 ']
#  ['50mg' '135'
#   'https://www.medchemexpress.com/search.html?q=HY-10320&amp;ft=&amp;fa=&amp;fp='
#   'ZINC24044436 ']
#  ['100mg' '185'
#   'https://www.medchemexpress.com/search.html?q=HY-10320&amp;ft=&amp;fa=&amp;fp='
#   'ZINC24044436 ']]
# [['5mg' '103.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=PZ0191|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC35902489 ']]
# []
# []
# [['4l' '204.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=GHS1128|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC00155806 ']]
# [['500ml' '40.10'
#   'http://www.sigmaaldrich.com/catalog/search?term=GHS116|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC00155806 ']]
# [['1l' '70.40'
#   'http://www.sigmaaldrich.com/catalog/search?term=GHS132|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC00155806 ']]
# [['1mg' '117' 'https://mcule.com/MCULE-1185498497/' 'ZINC16693864 ']
#  ['5mg' '117' 'https://mcule.com/MCULE-1185498497/' 'ZINC16693864 ']
#  ['10mg' '117' 'https://mcule.com/MCULE-1185498497/' 'ZINC16693864 ']]
# [['10mg' '57.00' 'https://www.targetmol.com/search?keyword=T3113'
#   'ZINC43204048 ']
#  ['25mg' '115.00' 'https://www.targetmol.com/search?keyword=T3113'
#   'ZINC43204048 ']
#  ['50mg' '208.00' 'https://www.targetmol.com/search?keyword=T3113'
#   'ZINC43204048 ']
#  ['100mg' '360.00' 'https://www.targetmol.com/search?keyword=T3113'
#   'ZINC43204048 ']
#  ['1mL*10mM(inDMSO)' '64.00'
#   'https://www.targetmol.com/search?keyword=T3113' 'ZINC43204048 ']]
# [['10mM*1mLinDMSO' '84'
#   'https://www.medchemexpress.com/search.html?q=HY-10338&amp;ft=&amp;fa=&amp;fp='
#   'ZINC43204048 ']
#  ['5mg' '60'
#   'https://www.medchemexpress.com/search.html?q=HY-10338&amp;ft=&amp;fa=&amp;fp='
#   'ZINC43204048 ']
#  ['10mg' '84'
#   'https://www.medchemexpress.com/search.html?q=HY-10338&amp;ft=&amp;fa=&amp;fp='
#   'ZINC43204048 ']
#  ['50mg' '264'
#   'https://www.medchemexpress.com/search.html?q=HY-10338&amp;ft=&amp;fa=&amp;fp='
#   'ZINC43204048 ']]
# [['5mg' '199.00'
#   'http://www.sigmaaldrich.com/catalog/search?term=B178|SIGMA&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product'
#   'ZINC12428433 ']]
# []

# %% [markdown]
# ### Affordability Filter

# %%
affordable = []

desiredlimit = 100.0
desiredsize = "10mg"

for b in buylist:
    for pr in b:
        if str(pr[0]) in desiredsize:
            if float(pr[1]) <= desiredlimit:
                affordable.append(pr)
                
affordable = np.array(affordable)
affordable = affordable[np.argsort(affordable[:,1])]

# %% [markdown]
# ### Results

# %%
data = {'ZINC ID': affordable[:,3],'Package Size': affordable[:,0], 'Price ($)': affordable[:,1],'Link': affordable[:,2]}
pd.set_option('display.max_colwidth', -1)
df = pd.DataFrame(data=data)
display(df)
# Out:
#           ZINC ID Package Size Price ($)  \
# 0   ZINC01420826   10mg         50.00
# 1   ZINC24044436   10mg         50.00
# 2   ZINC02043204   10mg         51.00
# 3   ZINC00006989   10mg         56.00
# 4   ZINC43204048   10mg         57.00
# 5   ZINC03815700   10mg         60
# 6   ZINC18274812   10mg         60
# 7   ZINC18274812   10mg         60
# 8   ZINC24044436   10mg         60
# 9   ZINC00006486   10mg         63.50
# 10  ZINC00244029   10mg         82.00
# 11  ZINC43204048   10mg         84
# 12  ZINC08830553   10mg         96
#
#                                                                                                                                                                    Link
# 0   https://www.targetmol.com/search?keyword=T2623
# 1   https://www.targetmol.com/search?keyword=T6277
# 2   https://www.targetmol.com/search?keyword=T6250
# 3   https://www.targetmol.com/search?keyword=T1725
# 4   https://www.targetmol.com/search?keyword=T3113
# 5   https://www.medchemexpress.com/search.html?q=HY-10256A&amp;ft=&amp;fa=&amp;fp=
# 6   https://www.medchemexpress.com/search.html?q=HY-10256A&amp;ft=&amp;fa=&amp;fp=
# 7   https://www.medchemexpress.com/search.html?q=HY-10256&amp;ft=&amp;fa=&amp;fp=
# 8   https://www.medchemexpress.com/search.html?q=HY-10320&amp;ft=&amp;fa=&amp;fp=
# 9   http://www.sigmaaldrich.com/catalog/search?term=CDS021620|ALDRICH&amp;interface=All&amp;N=0&amp;mode=match%20partialmax&amp;lang=en&amp;region=US&amp;focus=product
# 10  https://www.targetmol.com/search?keyword=T2234
# 11  https://www.medchemexpress.com/search.html?q=HY-10338&amp;ft=&amp;fa=&amp;fp=
# 12  https://www.medchemexpress.com/search.html?q=HY-15535&amp;ft=&amp;fa=&amp;fp=
